# %%
import pandas as pd

# %%
data=pd.read_csv("survey.csv")

# %%
data
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
data.shape
# Out:
# (41715, 10)

# %%
data.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
data.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 41710  Food product manufacturing  Percentage           H37
# 41711  Food product manufacturing  Percentage           H38
# 41712  Food product manufacturing  Percentage           H39
# 41713  Food product manufacturing  Percentage           H40
# 41714  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 41710                          Quick ratio  Financial ratios    52
# 41711  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
data.Units
# Out:
# 0        Dollars (millions)
# 1        Dollars (millions)
# 2        Dollars (millions)
# 3        Dollars (millions)
# 4        Dollars (millions)
#                 ...
# 41710            Percentage
# 41711            Percentage
# 41712            Percentage
# 41713            Percentage
# 41714            Percentage
# Name: Units, Length: 41715, dtype: object

# %%
data.Units.unique()
# Out:
# array(['Dollars (millions)', 'Dollars', 'Percentage'], dtype=object)

# %%
data.Units.shape
# Out:
# (41715,)

# %%
data["Units"]
# Out:
# 0        Dollars (millions)
# 1        Dollars (millions)
# 2        Dollars (millions)
# 3        Dollars (millions)
# 4        Dollars (millions)
#                 ...
# 41710            Percentage
# 41711            Percentage
# 41712            Percentage
# 41713            Percentage
# 41714            Percentage
# Name: Units, Length: 41715, dtype: object

# %%
data.Units.value_counts()
# Out:
# Units
# Dollars (millions)    32796
# Percentage             6633
# Dollars                2286
# Name: count, dtype: int64

# %%
data.Units.value_counts().sum()
# Out:
# 41715

# %%
data.Units.value_counts(normalize=True)
# Out:
# Units
# Dollars (millions)    0.786192
# Percentage            0.159008
# Dollars               0.054800
# Name: proportion, dtype: float64

# %%
data.Units.describe()
# Out:
# count                  41715
# unique                     3
# top       Dollars (millions)
# freq                   32796
# Name: Units, dtype: object

# %%
data.Units.unique()
# Out:
# array(['Dollars (millions)', 'Dollars', 'Percentage'], dtype=object)

# %%
data.Units.nunique()
# Out:
# 3

# %%
data.Year.describe()
# Out:
# count    41715.00000
# mean      2017.00000
# std          2.58202
# min       2013.00000
# 25%       2015.00000
# 50%       2017.00000
# 75%       2019.00000
# max       2021.00000
# Name: Year, dtype: float64

# %%
pd.crosstab(data.Year,data.Industry_aggregation_NZSIOC)
# Out:
# Industry_aggregation_NZSIOC  Level 1  Level 3  Level 4
# Year
# 2013                             559     1539     2537
# 2014                             559     1539     2537
# 2015                             559     1539     2537
# 2016                             559     1539     2537
# 2017                             559     1539     2537
# 2018                             559     1539     2537
# 2019                             559     1539     2537
# 2020                             559     1539     2537
# 2021                             559     1539     2537

# %%
pd.crosstab(data.Year,data.Industry_aggregation_NZSIOC,normalize=True)
# Out:
# Industry_aggregation_NZSIOC  Level 1   Level 3   Level 4
# Year
# 2013                          0.0134  0.036893  0.060817
# 2014                          0.0134  0.036893  0.060817
# 2015                          0.0134  0.036893  0.060817
# 2016                          0.0134  0.036893  0.060817
# 2017                          0.0134  0.036893  0.060817
# 2018                          0.0134  0.036893  0.060817
# 2019                          0.0134  0.036893  0.060817
# 2020                          0.0134  0.036893  0.060817
# 2021                          0.0134  0.036893  0.060817

# %%
data.loc[[0,3,6]]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 6  2021                     Level 1                99999       All industries
#
#                 Units Variable_code         Variable_name  \
# 0  Dollars (millions)           H01          Total income
# 3  Dollars (millions)           H07  Non-operating income
# 6  Dollars (millions)           H10        Indirect taxes
#
#        Variable_category    Value  \
# 0  Financial performance  757,504
# 3  Financial performance   33,020
# 6  Financial performance    6,991
#
#                               Industry_code_ANZSIC06
# 0  ANZSIC06 divisions A-S (excluding classes K633...
# 3  ANZSIC06 divisions A-S (excluding classes K633...
# 6  ANZSIC06 divisions A-S (excluding classes K633...

# %%
data.loc[[0,3,6],["Units","Variable_code","Value"]]
# Out:
#                 Units Variable_code    Value
# 0  Dollars (millions)           H01  757,504
# 3  Dollars (millions)           H07   33,020
# 6  Dollars (millions)           H10    6,991

# %%
data.loc[:,"Units"]      #all rows one column
# Out:
# 0        Dollars (millions)
# 1        Dollars (millions)
# 2        Dollars (millions)
# 3        Dollars (millions)
# 4        Dollars (millions)
#                 ...
# 41710            Percentage
# 41711            Percentage
# 41712            Percentage
# 41713            Percentage
# 41714            Percentage
# Name: Units, Length: 41715, dtype: object

# %%
data.loc[1,:]
# Out:
# Year                                                                        2021
# Industry_aggregation_NZSIOC                                              Level 1
# Industry_code_NZSIOC                                                       99999
# Industry_name_NZSIOC                                              All industries
# Units                                                         Dollars (millions)
# Variable_code                                                                H04
# Variable_name                    Sales, government funding, grants and subsidies
# Variable_category                                          Financial performance
# Value                                                                    674,890
# Industry_code_ANZSIC06         ANZSIC06 divisions A-S (excluding classes K633...
# Name: 1, dtype: object

# %%
data.loc[[0,4,7,8]]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
# 7  2021                     Level 1                99999       All industries
# 8  2021                     Level 1                99999       All industries
#
#                 Units Variable_code            Variable_name  \
# 0  Dollars (millions)           H01             Total income
# 4  Dollars (millions)           H08        Total expenditure
# 7  Dollars (millions)           H11             Depreciation
# 8  Dollars (millions)           H12  Salaries and wages paid
#
#        Variable_category    Value  \
# 0  Financial performance  757,504
# 4  Financial performance  654,404
# 7  Financial performance   27,801
# 8  Financial performance  123,620
#
#                               Industry_code_ANZSIC06
# ...

# %%
data.loc[[0,4,7,8],["Year","Units"]]
# Out:
#    Year               Units
# 0  2021  Dollars (millions)
# 4  2021  Dollars (millions)
# 7  2021  Dollars (millions)
# 8  2021  Dollars (millions)

# %%
data.loc[:,"Year"]        #All rows one column
# Out:
# 0        2021
# 1        2021
# 2        2021
# 3        2021
# 4        2021
#          ...
# 41710    2013
# 41711    2013
# 41712    2013
# 41713    2013
# 41714    2013
# Name: Year, Length: 41715, dtype: int64

# %%
data.loc[[1,4,8,40000]]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 1      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# 8      2021                     Level 1                99999
# 40000  2013                     Level 4                II131
#
#                                    Industry_name_NZSIOC               Units  \
# 1                                        All industries  Dollars (millions)
# 4                                        All industries  Dollars (millions)
# 8                                        All industries  Dollars (millions)
# 40000  Postal and Courier Pick Up and Delivery Services          Percentage
#
#       Variable_code                                    Variable_name  \
# 1               H04  Sales, government funding, grants and subsidies
# 4               H08                                Total expenditure
# ...

# %%
data.loc[:,["Year","Value","Units"]]          #All rows multiple columns
# Out:
#        Year    Value               Units
# 0      2021  757,504  Dollars (millions)
# 1      2021  674,890  Dollars (millions)
# 2      2021   49,593  Dollars (millions)
# 3      2021   33,020  Dollars (millions)
# 4      2021  654,404  Dollars (millions)
# ...     ...      ...                 ...
# 41710  2013       52          Percentage
# 41711  2013       40          Percentage
# 41712  2013       12          Percentage
# 41713  2013        5          Percentage
# 41714  2013       46          Percentage
#
# [41715 rows x 3 columns]

# %%
data.loc[0:10:2]
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2021                     Level 1                99999
# 2   2021                     Level 1                99999
# 4   2021                     Level 1                99999
# 6   2021                     Level 1                99999
# 8   2021                     Level 1                99999
# 10  2021                     Level 1                99999
#
#    Industry_name_NZSIOC               Units Variable_code  \
# 0        All industries  Dollars (millions)           H01
# 2        All industries  Dollars (millions)           H05
# 4        All industries  Dollars (millions)           H08
# 6        All industries  Dollars (millions)           H10
# 8        All industries  Dollars (millions)           H12
# 10       All industries  Dollars (millions)           H14
#
#                                         Variable_name      Variable_category  \
# ...

# %%
data.loc[1:10:2]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 1  2021                     Level 1                99999       All industries
# 3  2021                     Level 1                99999       All industries
# 5  2021                     Level 1                99999       All industries
# 7  2021                     Level 1                99999       All industries
# 9  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 1  Dollars (millions)           H04
# 3  Dollars (millions)           H07
# 5  Dollars (millions)           H09
# 7  Dollars (millions)           H11
# 9  Dollars (millions)           H13
#
#                                      Variable_name      Variable_category  \
# 1  Sales, government funding, grants and subsidies  Financial performance
# 3                             Non-operating income  Financial performance
# ...

# %%
data.loc[0:3,["Year","Units"]]
# Out:
#    Year               Units
# 0  2021  Dollars (millions)
# 1  2021  Dollars (millions)
# 2  2021  Dollars (millions)
# 3  2021  Dollars (millions)

# %%
data.iloc[0:3,[0,5]]
# Out:
#    Year Variable_code
# 0  2021           H01
# 1  2021           H04
# 2  2021           H05

# %%
ct=pd.crosstab(data.Year,data.Industry_aggregation_NZSIOC)

# %%
ct.plot(kind="bar")
# Out:
# <Axes: xlabel='Year'>

# %%
ct.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Year'>

# %%
import pandas as pd

# %%
data=pd.read_csv("cardekho_dataset.csv")

# %%
data
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
data1=pd.read_csv("COVID19Cases.csv")
# Out:
# C:\Users\lyric\AppData\Local\Temp\ipykernel_20308\3342526129.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1=pd.read_csv("COVID19Cases.csv")

# %%
data1
# Out:
#         Case_Type  People_Total_Tested_Count  Cases  Difference       Date  \
# 0       Confirmed                        NaN      6           0  5/22/2020
# 1       Confirmed                        NaN      0           0   2/3/2020
# 2          Deaths                        NaN      0           0   3/1/2020
# 3       Confirmed                        NaN     23           0  4/21/2020
# 4          Deaths                        NaN     56           0  5/11/2020
# ...           ...                        ...    ...         ...        ...
# 950665     Deaths                        NaN      0           0  1/22/2020
# 950666  Confirmed                        NaN      0           0  1/22/2020
# 950667     Deaths                        NaN      0           0  1/22/2020
# 950668  Confirmed                        NaN      0           0  1/22/2020
# 950669  Confirmed                        NaN      0           0  1/22/2020
#
# ...

# %%
data1.dtypes
# Out:
# Case_Type                                object
# People_Total_Tested_Count               float64
# Cases                                     int64
# Difference                                int64
# Date                                     object
# Combined_Key                             object
# Country_Region                           object
# Province_State                           object
# Admin2                                   object
# iso2                                     object
# iso3                                     object
# FIPS                                    float64
# Lat                                     float64
# Long                                    float64
# Population_Count                        float64
# People_Hospitalized_Cumulative_Count    float64
# Data_Source                              object
# Prep_Flow_Runtime                        object
# dtype: object

# %%
data1.Cases.sum()
# Out:
# 260025979

# %%
data1.Lat.max()
# Out:
# 71.7069

# %%
data1.Long.max()
# Out:
# 178.065

# %%
data1.Case_Type.unique()
# Out:
# array(['Confirmed', 'Deaths'], dtype=object)

# %%
data1.Case_Type.value_counts()
# Out:
# Case_Type
# Confirmed    475335
# Deaths       475335
# Name: count, dtype: int64

# %%
pd.crosstab(data1.Case_Type,data1.Country_Region)
# Out:
# Country_Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# Case_Type
# Confirmed               135      135      135      135     135
# Deaths                  135      135      135      135     135
#
# Country_Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# Case_Type
# Confirmed                       135        135      135       1080      135
# Deaths                          135        135      135       1080      135
#
# Country_Region  ...  United Kingdom  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# Case_Type       ...
# Confirmed       ...            1485      135         135        135      135
# Deaths          ...            1485      135         135        135      135
#
# Country_Region  West Bank and Gaza  Western Sahara  Yemen  Zambia  Zimbabwe
# Case_Type
# Confirmed                      135             135    135     135       135
# Deaths                         135             135    135     135       135
#
# [2 rows x 187 columns]

# %%
pd.crosstab(data1.Country_Region,data1.Cases)
# Out:
# Cases               0       1       2       3       4       5       6       \
# Country_Region
# Afghanistan             93      16       1       0       9       1       2
# Albania                 96       7       6       0       1       2       1
# Algeria                 84       7       1       2       3       1       0
# Andorra                100      18       1       3       0       0       1
# Angola                 125       1      52       8      15       1       0
# ...                    ...     ...     ...     ...     ...     ...     ...
# West Bank and Gaza     107      15      43      13       1       0       0
# Western Sahara         199      10       0       0       7       0      42
# Yemen                  178      19       5       0       1       2       2
# Zambia                 127       8      13      20       3       0       0
# Zimbabwe               119      16       1      20      44       1       0
#
# ...

# %%
pd.crosstab(data1.Country_Region,data1.Population_Count)
# Out:
# Population_Count    8.600000e+01  1.690000e+02  2.720000e+02  4.040000e+02  \
# Country_Region
# Afghanistan                    0             0             0             0
# Albania                        0             0             0             0
# Algeria                        0             0             0             0
# Andorra                        0             0             0             0
# Angola                         0             0             0             0
# ...                          ...           ...           ...           ...
# West Bank and Gaza             0             0             0             0
# Western Sahara                 0             0             0             0
# Yemen                          0             0             0             0
# Zambia                         0             0             0             0
# Zimbabwe                       0             0             0             0
#
# ...

# %%
data2=pd.read_json("unece.json")

# %%
data2
# Out:
#         Country  Year  Area (square kilometres)  Total population  \
# 0       Albania  2000                   28748.0         3401198.0
# 1       Albania  2001                   28748.0         3073734.0
# 2       Albania  2002                   28748.0         3093465.0
# 3       Albania  2003                   28748.0         3111162.0
# 4       Albania  2004                   28748.0         3127264.0
# ..          ...   ...                       ...               ...
# 879  Uzbekistan  2012                  447400.0        29774448.0
# 880  Uzbekistan  2013                  447400.0        30243172.0
# 881  Uzbekistan  2014                  447400.0        30757669.0
# 882  Uzbekistan  2015                  447400.0        31298929.0
# 883  Uzbekistan  2016                  447400.0               NaN
#
#      Population density, pers. per sq. km  Population aged 0-14, male  \
# 0                               118.31077                    564851.0
# ...

# %%
data3=pd.read_excel("titanic_modified_NA.xlsx")

# %%
data3
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data4=pd.read_csv("https://raw.githubusercontent.com/pwskills123/pwioidatascience/main/pandas/vgsalesGlobale.csv")

# %%
data4
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data5=pd.read_html("https://en.wikipedia.org/wiki/Animal")

# %%
data5
# Out:
# [   Animals Temporal range: Cryogenian – present, 665–0 Ma Pha. Proterozoic Archean Had.  \
#  0                                                 NaN
#  1                           Scientific classification
#  2                                             Domain:
#  3                                              Clade:
#  4                                              Clade:
#  5                                         (unranked):
#  6                                         (unranked):
#  7                                         (unranked):
#  8                                            Kingdom:
#  9                                        Subdivisions
#  10  Bilateria (~30 phyla) Cnidaria Ctenophora Plac...
#  11                                           Synonyms
#  12  Metazoa Haeckel 1874[1] Choanoblastaea Nielsen...
#
#     Animals Temporal range: Cryogenian – present, 665–0 Ma Pha. Proterozoic Archean Had..1
#  0                                                 NaN
# ...

# %%
data5[0]
# Out:
#    Animals Temporal range: Cryogenian – present, 665–0 Ma Pha. Proterozoic Archean Had.  \
# 0                                                 NaN
# 1                           Scientific classification
# 2                                             Domain:
# 3                                              Clade:
# 4                                              Clade:
# 5                                         (unranked):
# 6                                         (unranked):
# 7                                         (unranked):
# 8                                            Kingdom:
# 9                                        Subdivisions
# 10  Bilateria (~30 phyla) Cnidaria Ctenophora Plac...
# 11                                           Synonyms
# 12  Metazoa Haeckel 1874[1] Choanoblastaea Nielsen...
#
#    Animals Temporal range: Cryogenian – present, 665–0 Ma Pha. Proterozoic Archean Had..1
# 0                                                 NaN
# ...

# %%
len(data5)
# Out:
# 84

# %%
import pandas as pd

# %%
import numpy as np

# %%
s=pd.Series([1,2,3,4,5],index=["a","b","c","d","e"])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s.drop("b")
# Out:
# a    1
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1=pd.Series(np.arange(5.),index=["a","b","c","d","e"])

# %%
s1
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
data=pd.DataFrame(np.arange(16).reshape(4,4),index=["Rohit","Krish","Awadh","DG"],columns=list("ABCD"))

# %%
data
# Out:
#         A   B   C   D
# Rohit   0   1   2   3
# Krish   4   5   6   7
# Awadh   8   9  10  11
# DG     12  13  14  15

# %%
data.drop("DG")
# Out:
#        A  B   C   D
# Rohit  0  1   2   3
# Krish  4  5   6   7
# Awadh  8  9  10  11

# %%
data.drop("C",axis=1)
# Out:
#         A   B   D
# Rohit   0   1   3
# Krish   4   5   7
# Awadh   8   9  11
# DG     12  13  15

# %%
data.drop(["DG","Awadh"])
# Out:
#        A  B  C  D
# Rohit  0  1  2  3
# Krish  4  5  6  7

# %%
data.drop(["A","D"],axis=1)
# Out:
#         B   C
# Rohit   1   2
# Krish   5   6
# Awadh   9  10
# DG     13  14

# %%
df1=pd.DataFrame(
    np.arange(6).reshape(2,3),
    columns=list("ABC"),
    index=["Tim","Tom"])
df2=pd.DataFrame(
    np.arange(9).reshape(3,3),
    columns=list("ACD"),
    index=["Tim","Kate","Tom"])

# %%
df1
# Out:
#      A  B  C
# Tim  0  1  2
# Tom  3  4  5

# %%
df2
# Out:
#       A  C  D
# Tim   0  1  2
# Kate  3  4  5
# Tom   6  7  8

# %%
df1+df2       #1+nan=nan
# Out:
#         A   B     C   D
# Kate  NaN NaN   NaN NaN
# Tim   0.0 NaN   3.0 NaN
# Tom   9.0 NaN  12.0 NaN

# %%
data
# Out:
#         A   B   C   D
# Rohit   0   1   2   3
# Krish   4   5   6   7
# Awadh   8   9  10  11
# DG     12  13  14  15

# %%
data.mean()   #0+8+4+12=24
              #24/4=6.0
# Out:
# A    6.0
# B    7.0
# C    8.0
# D    9.0
# dtype: float64

# %%
data.mean(axis=1)     #0+1+2+3=6
                      #6/4=1.5
# Out:
# Rohit     1.5
# Krish     5.5
# Awadh     9.5
# DG       13.5
# dtype: float64

# %%
df1=pd.DataFrame(
    np.arange(6).reshape(2,3),
    columns=list("ABC"),
    index=["Krish","Awadh"])
df2=pd.DataFrame(
    np.arange(9).reshape(3,3),
    columns=list("ACD"),
    index=["Krish","DG","Awadh"])

# %%
df1
# Out:
#        A  B  C
# Krish  0  1  2
# Awadh  3  4  5

# %%
df2
# Out:
#        A  C  D
# Krish  0  1  2
# DG     3  4  5
# Awadh  6  7  8

# %%
df1*3
# Out:
#        A   B   C
# Krish  0   3   6
# Awadh  9  12  15

# %%
df1**3
# Out:
#         A   B    C
# Krish   0   1    8
# Awadh  27  64  125

# %%
1/df2
# Out:
#               A         C      D
# Krish       inf  1.000000  0.500
# DG     0.333333  0.250000  0.200
# Awadh  0.166667  0.142857  0.125

# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series(range(5),
            index=["e","d","a","b","c"])
s
# Out:
# e    0
# d    1
# a    2
# b    3
# c    4
# dtype: int64

# %%
s.sort_index()
# Out:
# a    2
# b    3
# c    4
# d    1
# e    0
# dtype: int64

# %%
df=pd.DataFrame(
    np.arange(12).reshape(3,4),
    index=["two","one","three"],
    columns=["d","a","b","c"])
df
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df.sort_index()
# Out:
#        d  a   b   c
# one    4  5   6   7
# three  8  9  10  11
# two    0  1   2   3

# %%
df.sort_index(axis=1)
# Out:
#        a   b   c  d
# two    1   2   3  0
# one    5   6   7  4
# three  9  10  11  8

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#        d   c   b  a
# two    0   3   2  1
# one    4   7   6  5
# three  8  11  10  9

# %%
df.sort_values(by="b")
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
df.sort_values(by="a")
# Out:
#        d  a   b   c
# two    0  1   2   3
# one    4  5   6   7
# three  8  9  10  11

# %%
import pandas as pd

# %%
da=pd.read_csv("coursera.csv")

# %%
da
# Out:
#      Unnamed: 0                                  Title  \
# 0             0                   Google Cybersecurity
# 1             1                  Google Data Analytics
# 2             3             Google Project Management:
# 3             4                       IBM Data Science
# 4             5  Google Digital Marketing & E-commerce
# ..          ...                                    ...
# 618         624              Google Workspace Security
# 619         625   Cybersecurity for Tech Professionals
# 620         626             Cybersecurity in the Cloud
# 621         627                   Applied Cryptography
# 622         628              Python for Active Defense
#
#                       Organization  \
# 0                           Google
# 1                           Google
# 2                           Google
# 3                              IBM
# 4                           Google
# ..                             ...
# 618                   Google Cloud
# ...

# %%
da.Ratings.max()
# Out:
# 5.0

# %%
pd.crosstab(da.Difficulty,da.Review Count)
# Out:
#   Cell In[5], line 1
#     pd.crosstab(da.Difficulty,da.Review Count)
#                               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
